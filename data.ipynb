# %%
import pandas as pd
import numpy as np
from eval_lib import *
import torch

# %%
def check_for_string(col, substr):
    string = col.str
    return string.startswith(substr + " ") | string.contains(" " + substr + " ") | string.endswith(" " + substr)

assert(check_for_string(pd.Series("hello you there"), "hello").all())
assert(check_for_string(pd.Series("hello you there"), "there").all())
assert(check_for_string(pd.Series("hello you there"), "you").all())
assert(not(check_for_string(pd.Series("hello you there"), "ello")).all())
print(check_for_string(pd.Series("hello you there"), "hello"))
# Out:
# 0    True
# dtype: bool

# %%
def print_pronoun_counts(file_path):
    print("Reading from %s" % file_path)
    new_df = pd.read_csv(file_path, sep='\t')
    new_df = new_df[new_df["tr"].notna()] # for some reason, two weird entries with NaN
    new_df = new_df[new_df["en"].notna()] 
    pronouns = new_df[check_for_string(new_df["tr"], "o")]
    # Number of examples with "o bir"
    print("# o bir", pronouns.shape[0])
    # Number of which translate to "he", roughly
    hes = pronouns[check_for_string(pronouns["en"], "he") | check_for_string(pronouns["en"], "he's")]
    print("o -> he", hes.shape[0])
    # Number of which translate to "she", roughly
    shes = pronouns[check_for_string(pronouns["en"], "she") | check_for_string(pronouns["en"], "she's")]
    print("o -> she", shes.shape[0])
    its = pronouns[check_for_string(pronouns["en"], "it") | check_for_string(pronouns["en"], "it's")]
    print("o -> it", its.shape[0])
    return pronouns

# %%
male_pronouns = set(["he", "he's", "his", "him", "he'll"])
female_pronouns = set(["she", "she's", "hers", "her", "she'll"])

# %%
# Returns true if col.str has one of any of the set of strings.
def check_for_set_of_strings(col, iter_of_strings):
    init_bool = np.zeros(len(col), dtype=bool)
    for substr in iter_of_strings:
        init_bool = init_bool | check_for_string(col, substr)
    return init_bool

assert(check_for_set_of_strings(pd.Series("hello you there"), ["hello"]).all())

# %%
train_df = pd.read_csv('data/train_200k.csv', sep='\t')

# %%
print("fem", train_df[check_for_set_of_strings(train_df['en'], female_pronouns)].shape)
print("masc", train_df[check_for_set_of_strings(train_df['en'], male_pronouns)].shape)
print("overlap", train_df[check_for_set_of_strings(train_df['en'], male_pronouns) & check_for_set_of_strings(train_df['en'], female_pronouns)].shape)
# Out:
# fem (8158, 4)
# masc (14821, 4)
# overlap (362, 4)

# %%
print(14821.0 /(14821 + 8158))
# Out:
# 0.6449801993124157

# %%
print(14821 + 8158 - 362)
print(22617.0 / 2E6)
# Out:
# 22617
# 0.0113085

# %%
print_pronoun_counts("data/val_10k_0306.csv")
# Out:
# Reading from data/val_10k_0306.csv
# # o bir 1823
# o -> he 356
# o -> she 214
# o -> it 279
#                                               tr_context  \
# 95     michael , şu küçük koreli geldi , ve onla ne y...
# 102                                             döndüm .
# 164                 " selam , dans etmek ister misin ? "
# 200    görüyor musun , george michael sana bu posteri...
# 245                               vay canına , michael .
# 304                                              bende .
# 307    stanton ve ben iki yaşındayken , annemiz onun ...
# 384                          yeterince açık , değil mi ?
# 528    baştan bu kadar korkunç olacağını bilseydim , ...
# 539    bana mı öyle geliyor , yoksa burası daha da so...
# 560                        kadınlar bölüm de varmış mı ?
# 576                                              güzel .
# 625                                      bana bakmayın .
# 729                                              orada .
# 731                                         vay canına !
# 758                                           haklısın .
# 767                                        rol yapıyor .
# 837                                              bekle .
# 878    bunu bir politikacıdan duymak hoşuna gitmiyor ...
# 882    sadece londralı sevgilim olmaya devam etsen da...
# 928    modellerimiz , 48 saat içinde bir saldırı olma...
# 1046                                başka şansım yoktu .
# 1095              bilirsin , eve para gönderen aileler .
# 1100                                            pekâlâ .
# 1135   baskı altında birini görünce az daha bastırmay...
# 1147                            kadın fsb ' nin elinde .
# 1183        harry o siber saldırıyı tek başına yapmadı .
# 1196                   sonunda gerçekleştiğindeki neşe .
# 1217   kadın fsb gözaltından çıktığında , qasim bana ...
# 1298                                                al .
# ...                                                  ...
# 54888       i̇yi ki karınla konuşmana izin vermiyorlar .
# 54942                           sen aklını kaçırmışsın .
# 54957               her zamankinden daha zorlu değildi .
# 54967                                   i̇htiyacım yok .
# 54997                              pekala , bu ilkiydi .
# 55049                               bu yeterli olur mu ?
# 55060                        her zaman kafayı bulurdum .
# 55093              boynuzlu tavşan diye bir şey yoktur .
# 55113  evet , seni hayal kırıklığına uğratmak istemem...
# 55120                   hem unuttun mu , ben ölümsüzüm .
# 55160                   patlayıcılar konusunda uzmandı .
# 55162                                 öyle mi kabadayı ?
# 55175                                    dave , lütfen !
# 55177          ama bu hikâyenin gerisi var , inan bana !
# 55189                        i̇yi olduğunu , biliyorum .
# 55219  bir süre sonra birileri bu işi eşelemeye başla...
# 55253                                            tabii !
# 55277               bazen kendi satın alır bazen almaz .
# 55320  niyetimiz , new york ' ta tutuklandığınızda , ...
# 55364                    başarabileceğimizi sanıyordum .
# 55393           çevresi geniştir , ne yapacağını bilir .
# 55411                                   şimdi şuna bak :
# 55412                                     hem de nasıl !
# 55419    keaton ' ın vurulduğunu gördüm , yemin ederim .
# 55425  muhtemelen , söze ' nin türkiye ' de kökünü ku...
# 55434                                             edie !
# 55436  yutmuş olsam bile , onu korumak için seni gönd...
# 55444                                          edie mi ?
# 55504                               steve jobs da öyle .
# 55505  üniversitelere özgü bir aldatmacadan başka bir...
#
#                                                       tr  \
# 95                              en azından , sanırım o .
# 102                                              kim o ?
# 164    ve o da şöyle bir şey , diyeceğini düşündüm , ...
# 200     biliyor musun , o sana , aşık gibi , bu yüzden .
# 245    sana o kadar kötü davrandıktan sonra , beni ko...
# 304    o benim kardeşim stanton ; şartlı tahliye memu...
# 307                                           o bilmez .
# 384               tamam o zaman , haydi parti başlasın .
# 528              haydi ahbap , o kadarda kötü değildir .
# 539                                     evet , o haklı .
# 560    ve o lanet kaçık müdür kadınlar bölümünün etra...
# 576                                   scelzi , o nedir ?
# 625    bak , connie , o herifi dışarı çıkarmak zorund...
# 729                          tekrar o adam , gördün mü ?
# 731                                           o da kim ?
# 758                               o gerçek bir hayalet .
# 767                              scelzi nerede o zaman ?
# 837                                           o sensin .
# 878    o asansörün sadece acil durumlar için olduğunu...
# 882               o pozisyon uzun süre açık kalmayacak .
# 928    ne kadar baskı altına girerse , penceresi o ka...
# 1046                      haine olan tek bağlantımız o .
# 55434       i don 't buy the reform story for a minute .
# 55436                                           so why ?
# 55444       he used all of you to get him on that boat .
# 55504           that 's that center for the blackhawks ?
# 55505  i 'm glad that place didn 't turn you into an ...
#
# [1823 rows x 4 columns]

# %%
print_pronoun_counts("data/train_200k.csv")
# Out:
# Reading from data/train_200k.csv
# # o bir 61542
# o -> he 11582
# o -> she 6186
# o -> it 7477
#                                                 tr_context  \
# 27       tüm gün pislik yerim, düşene kadar içerim, anl...
# 38                                evet son düzlüğe girdik.
# 39                                        teşekkür ederim.
# 45                                     i̇şte benim adamım.
# 55            i̇şte telefonu cevapladığınızda bunlar olur.
# 120                  bu beni, ayrılık şarkısına sürükledi.
# 121                           # o gidince güneş de gitti #
# 122                            # o gidince sıcak olmuyor #
# 126                                                      #
# 128                            # ve bu ev, ev gibi değil #
# 136                   daha önce hiç ölümüne kankam olmadı.
# 137                  sadece jimmy'yi korumaya çalışıyoruz.
# 143             kalbi, rachel'ı yeniden görmeye dayanamaz.
# 156      "eğer ilişkimiz bir film olsaydı adı 'çarpışma...
# 183                        parçalarını da biz topluyorduk.
# 184                           # o gidince güneş de gitti #
# 185                            # o gidince sıcak olmuyor #
# 189                                                      #
# 191                            # ve bu ev, ev gibi değil #
# 229                                         tam buna göre.
# 238                          kanguru nerede, tanrı aşkına?
# 267      tıp öğrencisi, spor deodorant seviyor cüzdanın...
# 280             sanırım birileri prova boyunca seni kesti.
# 336                  dur, üzgünüm, ben başlarda kayboldum.
# 337      o akılsız market sahibinin içeri girdiği yerde...
# 354                                   i̇yi tarafından bak.
# 355      bizim sayemizde, arkadaşlığınız uzun sürmedi d...
# 358                                      i̇yi iş çıkardık.
# 359                           # o gidince güneş de gitti #
# 361                            # ve bu ev, ev gibi değil #
# ...                                                    ...
# 1999199                         sidik çocuğuna benziyorum.
# 1999226                                            berbat.
# 1999228  kısa süre önce bir dedikodu vardı bir devrimle...
# 1999301                                     kaldırın bunu.
# 1999314                                   oh, zavallı ben.
# 1999436  bir de bir sürü çocuk hala onların parti afişi...
# 1999482  ama michael'ın arabasıyla attıkları tur, lucil...
# 1999493     senin duvarını ilerletip banyosunu genişletti.
# 1999527                     ben olsam beşik bile isterdim.
# 1999534                         bana bir rövanş borçlusun.
# 1999579               i̇yi bir dövüşmeyi asla pas geçemem.
# 1999582                                        hadi, xena.
# 1999619  ne zaman aşiretlerimiz biraraya gelerek savaşm...
# 1999637       hiçbirşeyi reddetmemekle ilgili ne demiştin?
# 1999647  ama, şu var ki, bu insanların yardıma ihtiyacı...
# 1999648   eğer romalılar'ı tanıyan biri varsa, o da biziz.
# 1999663                                     evet, baba, o.
# 1999673       yakın zamanda, komşu kasabayı işgal ettiler.
# 1999732                            bence artık durmalıyız!
# 1999781                  korah'ı geri getiremez, değil mi?
# 1999799                                        onu bulduk.
# 1999809  bir romalı'yı rastgele seçip  i̇şlememiş olabi...
# 1999811                                          bekleyin!
# 1999815                                  tazir'in kampına.
# 1999819  ve gabrielle'i öldürseniz de, romalılar gelmey...
# 1999825                              dayanılır gibi değil.
# 1999889  bunu değiştiremem   ama, halkının özgürlüğünü ...
# 1999943       ayrıca , bana yeğeneni ayarlamaya çalışıyor.
# 1999953                       bir saat sonra bara gideriz.
# 1999960                             i̇kisi birden ,dostum.
#
#                                                         tr  \
# 27       sonuna kadar lock-up'ı izleyebilirim, 'çünkü o...
# 38       o kadar uzun süre ellerine hakim olabiliceğini...
# 39       neşelendirici ama bir o kadar da korkutucu ola...
# 45             hey, ne yapıyor... hayır, o burada olamaz..
# 55       bu gece yaptığın o muhteşem konuşmadan sonra s...
# 120                           # o gidince güneş de gitti #
# 121                            # o gidince sıcak olmuyor #
# 122                           # o gidince güneş de gitti #
# 126                           # o gidince güneş de gitti #
# 128                                          # o gidince #
# 136      sonunda o saçma kelimeyi kullanabileceğim biri...
# 137      görünen o ki, biz onu senden daha çok önemsiyo...
# 143           bu yüzden sana o kapıyı açmayı yasaklıyorum.
# 156      bunu yedi sene önce yazdığımda o film akademi ...
# 183                           # o gidince güneş de gitti #
# 184                            # o gidince sıcak olmuyor #
# 185                           # o gidince güneş de gitti #
# 189                           # o gidince güneş de gitti #
# 191                                          # o gidince #
# 229      o kızları bırakması gerektiğini öğrendi sanmış...
# 238                      o filmi rüyanda gördüğüne eminim.
# 267             o ve rachel birbirleri için yaratılmışlar.
# 280                       o korkunç güvenlik görevlisi mi?
# 336      o akılsız market sahibinin içeri girdiği yerde...
# 337                           bu hikayede o var, değil mi?
# 354      bizim sayemizde, arkadaşlığınız uzun sürmedi d...
# 355                           # o gidince güneş de gitti #
# 358                           # o gidince güneş de gitti #
# 359                           # o gidince güneş de gitti #
# 361                                                  # o #
# ...                                                    ...
# 1999199         tehlikeyi ilk sezdiğimizde, o kral olacak.
# 1999226                                    düzelt o zaman.
# 1999228  ama eğer tahta bir dublör olursa, kral güvende...
# 1999301  şimdi bunu hapishanenin baş memuruna ver, ve o...
# 1999314                o kadar da şanslı değilsin, pierre.
# 1999436      o arabanın içinde görünmekten utanıyor musun?
# 1999482  o gece, tobias'ın planı çetesiyle beraber soka...
# 1999493                eşyaların o yüzden sarkıyor raftan.
# 1999527                    tamam o zaman, teşekkür ederim.
# 1999534  james, bana yedirdiğin o iğrenç midyeler haric...
# 1999579           o zaman onları daha dikkatli seçmelisin.
# 1999582                sen kimsin ki o ismi kullanıyorsun?
# 1999619  o kadar çok kan döküldü ki, bazen birleşmenin ...
# 1999637  sence o adamlar, uydurduğum "iffetli amazonlar...
# 1999647   eğer romalılar'ı tanıyan biri varsa, o da biziz.
# 1999648                              al benden de o kadar.
# 1999663  o ve muhteşem arkadaşı, bizi süpürdüler  ve ço...
# 1999673  o kadar çoktular ki ve her türlü direnişi bast...
# 1999732                            o zaman kuma gömülürüz!
# 1999781          xena, o adamın gerçeği bilmeye hakkı var.
# 1999799                                        katil o mu?
# 1999809    o yapmadıysa bile, onun gibi bir başkası yaptı.
# 1999811                                     katil o değil.
# 1999815                      o ölmeyi hak etmiyor, kahina.
# 1999819                                  o zaman gelirler.
# 1999825              o sana hayrandı ve sen onu katlettin.
# 1999889            belki o zaman ölümünün bir anlamı olur.
# 143            that is why i forbid you to open that door.
# 156      wh-when i wrote this, uh, seven years ago, tha...
# 183                  ♪ ain't no sunshine when she's gone ♪
# 184                      ♪ it's not warm when she's away ♪
# 185                  ♪ ain't no sunshine when she's gone ♪
# 189                  ♪ ain't no sunshine when she's gone ♪
# 191                               ♪ any time she goes away
# 229      we thought he had learned to leave those types...
# 238                 i'm pretty sure you dreamt that movie.
# 267      it's obvious he and rachel are perfect for eac...
# 280                     was it that creepy security guard?
# 336      could you go back to when the goofy grocery st...
# 337                               he's in this one, right?
# 354      because of us, you weren't friends for very lo...
# 355                  ♪ ain't no sunshine when she's gone ♪
# 358         sabrina: ♪ ain't no sunshine when she's gone ♪
# 359                  ♪ ain't no sunshine when she's gone ♪
# 361                                             ♪ any time
# ...                                                    ...
# 1999199    at the first sign of trouble, he shall be king.
# 1999226                                       well,fix it.
# 1999228  but if there is a double on the throne, the ki...
# 1999301  now,you give this to the head officer at the j...
# 1999314                              not so lucky, pierre.
# 1999436  listen, are you embarrassed to be seen in that...
# 1999482  that night, tobias's plan to change the street...
# 1999493          that's why all your stuff s sticking out.
# 1999527                  all right, well, i appreciate it.
# 1999534  well, james, other than those disgusting musse...
# 1999579     you should pick your fights more wisely, then.
# 1999582                     who are you to take that name?
# 1999619  there's been so much bloodshed, sometimes i th...
# 1999637  do you think those guys bought that "amazon ch...
# 1999647                     if anyone knows romans, we do.
# 1999648                                          i'll say.
# 1999663  she and her magnificent friend swept down on u...
# 1999673  they come in great numbers and overwhelm any r...
# 1999732                            we'll get covered over!
# 1999781  xena, that man out there deserves to know the ...
# 1999799                                   he's the killer?
# 1999809     if he didn't do it, someone just like him did.
# 1999811                               he isn't the killer.
# 1999815                she doesn't deserve to die, kahina.
# 1999819                                    then they will.
# 1999825            he admired you and you slaughtered him.
# 1999889         maybe his death'll have some meaning then.
# 1999943           dude, then bang the frickin' niece, man.
# 1999953         i want you blacked out by then, all right?
# 1999960        and i am going to savor every minute of it.
#
# [61542 rows x 4 columns]

# %%
stereotypes = pd.read_csv("data/pro_stereotype.tsv", sep="\t", header=None)

# %%
with open('data/male_occupations.txt', 'r') as myfile:
    male_occupations = [i.strip() for i in myfile.readlines()]

# %%
with open('data/female_occupations.txt', 'r') as myfile:
    female_occupations = [i.strip() for i in myfile.readlines()]

# %%
df = pd.read_csv("data/train_200k.csv", sep="\t")
df = df[df["tr"].notna()] # for some reason, two weird entries with NaN
df = df[df["en"].notna()] 
data_ratios = {} # ratio in
for i in range(len(stereotypes)):
    tr = stereotypes.iloc[i, 1]
    en = stereotypes.iloc[i, 3]
    occupation = en[8:-1] if i < 20 else en[9:-1] # he is vs she is
    
    # Count # of rows with "he" vs "she"
    mentions_df = df[df["en"].str.contains(occupation)]
    he_mentions = mentions_df[check_for_set_of_strings(mentions_df["en"], male_pronouns)]
    she_mentions = mentions_df[check_for_set_of_strings(mentions_df["en"], female_pronouns)]
    print("%s: %d total, %d male, %d female" % (occupation, len(mentions_df), len(he_mentions), len(she_mentions)))
    data_ratios[occupation] = len(he_mentions), len(she_mentions)
# Out:
# driver: 906 total, 122 male, 29 female
# supervisor: 97 total, 15 male, 1 female
# janitor: 77 total, 5 male, 1 female
# cook: 1571 total, 109 male, 106 female
# mover: 42 total, 0 male, 0 female
# laborer: 18 total, 4 male, 1 female
# construction worker: 14 total, 2 male, 0 female
# chief: 1565 total, 140 male, 40 female
# developer: 32 total, 2 male, 0 female
# carpenter: 83 total, 10 male, 2 female
# manager: 572 total, 66 male, 28 female
# lawyer: 1280 total, 215 male, 63 female
# farmer: 304 total, 34 male, 8 female
# salesperson: 5 total, 0 male, 0 female
# physician: 127 total, 22 male, 4 female
# guard: 1984 total, 267 male, 75 female
# analyst: 65 total, 12 male, 3 female
# mechanic: 219 total, 20 male, 5 female
# sheriff: 743 total, 63 male, 15 female
# CEO: 0 total, 0 male, 0 female
# attendant: 51 total, 5 male, 2 female
# cashier: 42 total, 6 male, 0 female
# teacher: 1107 total, 122 male, 81 female
# nurse: 762 total, 52 male, 64 female
# assistant: 491 total, 89 male, 30 female
# secretary: 472 total, 58 male, 28 female
# auditor: 33 total, 2 male, 0 female
# cleaner: 154 total, 20 male, 9 female
# receptionist: 55 total, 7 male, 6 female
# clerk: 140 total, 13 male, 9 female
# counselor: 220 total, 18 male, 12 female
# designer: 120 total, 13 male, 12 female
# hairdresser: 41 total, 2 male, 3 female
# writer: 463 total, 66 male, 24 female
# housekeeper: 75 total, 8 male, 9 female
# baker: 284 total, 19 male, 11 female
# accountant: 121 total, 23 male, 7 female
# editor: 182 total, 17 male, 15 female
# librarian: 38 total, 2 male, 2 female
# tailor: 84 total, 4 male, 0 female

# %%
for k, v in data_ratios.items():
    print("%s, %d, %d" % (k, v[0], v[1]))
# Out:
# driver, 122, 29
# supervisor, 15, 1
# janitor, 5, 1
# cook, 109, 106
# mover, 0, 0
# laborer, 4, 1
# construction worker, 2, 0
# chief, 140, 40
# developer, 2, 0
# carpenter, 10, 2
# manager, 66, 28
# lawyer, 215, 63
# farmer, 34, 8
# salesperson, 0, 0
# physician, 22, 4
# guard, 267, 75
# analyst, 12, 3
# mechanic, 20, 5
# sheriff, 63, 15
# CEO, 0, 0
# attendant, 5, 2
# cashier, 6, 0
# teacher, 122, 81
# nurse, 52, 64
# assistant, 89, 30
# secretary, 58, 28
# auditor, 2, 0
# cleaner, 20, 9
# receptionist, 7, 6
# clerk, 13, 9
# counselor, 18, 12
# designer, 13, 12
# hairdresser, 2, 3
# writer, 66, 24
# housekeeper, 8, 9
# baker, 19, 11
# accountant, 23, 7
# editor, 17, 15
# librarian, 2, 2
# tailor, 4, 0

# %%
def count_pronouns_with_antecedent(file_path):
    df = pd.read_csv(file_path, sep='\t')

# %%
def analyze_annotated_df(file_path):
    annotated_df = pd.read_csv(file_path, sep='\t')
    print("total rows:", annotated_df.shape[0])
    non_empty_df = annotated_df[(annotated_df['Unnamed: 4'] != '[]') & (annotated_df['Unnamed: 4'].notna())]
    print("Number of rows with a pronoun with antecedent in prev sentence:", non_empty_df.shape[0])
    print("fraction of total rows: ", non_empty_df.shape[0] / annotated_df.shape[0])
    print("Distribution of pronouns:")
    non_empty_df_o = non_empty_df[check_for_string(non_empty_df['tr'], "o")]
    print(non_empty_df_o['Unnamed: 4'].value_counts())
    return non_empty_df

# %%
ann_df_1 = analyze_annotated_df("data/train_200k_annotated.csv")
# Out:
# total rows: 226775
# Number of rows with a pronoun with antecedent in prev sentence: 14541
# fraction of total rows:  0.06412082460588689
# Distribution of pronouns:
# ['it']                                         336
# ['he']                                         124
# ['she']                                         73
# ['they']                                        39
# ['it', 'it']                                    36
# ['them']                                        31
# ['his']                                         24
# ['that']                                        22
# ['he', 'he']                                    14
# ['him']                                         12
# ['their']                                       11
# ['he', 'his']                                    7
# ['they', 'they']                                 7
# ['her']                                          6
# ['it', 'he']                                     5
# ['she', 'she']                                   5
# ['them', 'they']                                 5
# ['her', 'she']                                   4
# ['he', 'him']                                    4
# ['his', 'he']                                    4
# ['themselves']                                   3
# ['it', 'it', 'it']                               3
# ['you']                                          3
# ['he', 'he', 'him']                              2
# ['he', 'it']                                     2
# ['him', 'he']                                    2
# ['it', 'she']                                    2
# ['him', 'he', 'he']                              2
# ['them', 'he']                                   2
# ['it', 'that']                                   2
#                                               ...
# ['him', 'his']                                   1
# ['it', 'she', 'she', 'she', 'she']               1
# ['that', 'it']                                   1
# ['it', 'it', 'its']                              1
# ['his', 'he', 'his']                             1
# ['they', 'it']                                   1
# ['she', 'herself']                               1
# ['he', 'mine']                                   1
# ['they', 'us']                                   1
# ['she', 'he']                                    1
# ['it', 'they']                                   1
# ['they', 'them']                                 1
# ['its']                                          1
# ['they', 'them', 'they', 'they']                 1
# ['his', 'he', 'him']                             1
# ['themselves', 'it']                             1
# ['them', 'your', 'it']                           1
# ['you', 'you']                                   1
# ['she', 'she', 'it']                             1
# ['your', 'you']                                  1
# ['him', 'him', 'his', 'them', 'them', 'it']      1
# ['they', 'them', 'their']                        1
# ['his', 'he', 'his', 'him']                      1
# ['himself']                                      1
# ['they', 'they', 'their']                        1
# ['her', 'she', 'her']                            1
# ['that', 'he']                                   1
# ['she', 'his']                                   1
# ['he', 'he', 'he']                               1
# ['he', 'his', 'he', 'he']                        1
# Name: Unnamed: 4, Length: 84, dtype: int64

# %%
ann_df_2 = analyze_annotated_df("data/0308_train_200k_annotated_2.csv")
# Out:
# total rows: 319634
# Number of rows with a pronoun with antecedent in prev sentence: 20464
# fraction of total rows:  0.06402322656538416
# Distribution of pronouns:
# ['it']                                         9555
# ['they']                                       1735
# ['he']                                         1310
# ['them']                                       1036
# ['his']                                         749
# ['it', 'it']                                    628
# ['she']                                         607
# ['their']                                       528
# ['him']                                         527
# ['that']                                        507
# ['her']                                         370
# ['you']                                         266
# ['its']                                         171
# ['they', 'they']                                127
# ['he', 'he']                                    106
# ['he', 'his']                                    94
# ['themselves']                                   71
# ['itself']                                       68
# ['she', 'her']                                   67
# ['his', 'he']                                    60
# ['they', 'their']                                56
# ['she', 'she']                                   53
# ['they', 'them']                                 49
# ['he', 'him']                                    47
# ['they', 'it']                                   46
# ['himself']                                      45
# ['them', 'they']                                 43
# ['his', 'his']                                   36
# ['your']                                         35
# ['them', 'them']                                 35
#                                                ...
# ['it', "'em", 'they']                             1
# ['your', 'your', 'you']                           1
# ['its', 'his']                                    1
# ['he', 'me']                                      1
# ['it', 'he', 'he', 'he']                          1
# ['themselves', 'they']                            1
# ['them', 'your', 'it']                            1
# ['he', 'himself', 'his']                          1
# ['them', 'them', 'them', 'their']                 1
# ['mine']                                          1
# ['their', 'his', 'their']                         1
# ['herself', 'she', 'she', 'she']                  1
# ['them', 'them', 'their']                         1
# ['them', 'themselves']                            1
# ['my', 'him']                                     1
# ['his', 'he', 'she', 'her']                       1
# ['he', 'you', 'me', 'your']                       1
# ['he', 'them', 'him']                             1
# ['them', 'you']                                   1
# ['him', 'she']                                    1
# ['his', 'him', 'that']                            1
# ['he', 'his', 'it', 'it']                         1
# ['us', 'we']                                      1
# ['he', 'that', 'it']                              1
# ['them', 'them', 'them', 'they']                  1
# ['you', 'she', 'you']                             1
# ['it', 'that', 'it']                              1
# ['their', 'them', 'their', 'they']                1
# ['his', 'he', 'he', 'himself', 'he', 'his']       1
# ['he', 'his', 'me', 'it']                         1
# Name: Unnamed: 4, Length: 464, dtype: int64

# %%
ann_df_1[check_for_string(ann_df_1['tr'], 'o')]['Unnamed: 4'].value_counts()
# Out:
# ['it']                                         336
# ['he']                                         124
# ['she']                                         73
# ['they']                                        39
# ['it', 'it']                                    36
# ['them']                                        31
# ['his']                                         24
# ['that']                                        22
# ['he', 'he']                                    14
# ['him']                                         12
# ['their']                                       11
# ['he', 'his']                                    7
# ['they', 'they']                                 7
# ['her']                                          6
# ['it', 'he']                                     5
# ['she', 'she']                                   5
# ['them', 'they']                                 5
# ['her', 'she']                                   4
# ['he', 'him']                                    4
# ['his', 'he']                                    4
# ['themselves']                                   3
# ['it', 'it', 'it']                               3
# ['you']                                          3
# ['he', 'he', 'him']                              2
# ['he', 'it']                                     2
# ['him', 'he']                                    2
# ['it', 'she']                                    2
# ['him', 'he', 'he']                              2
# ['them', 'he']                                   2
# ['it', 'that']                                   2
#                                               ...
# ['him', 'his']                                   1
# ['it', 'she', 'she', 'she', 'she']               1
# ['that', 'it']                                   1
# ['it', 'it', 'its']                              1
# ['his', 'he', 'his']                             1
# ['they', 'it']                                   1
# ['she', 'herself']                               1
# ['he', 'mine']                                   1
# ['they', 'us']                                   1
# ['she', 'he']                                    1
# ['it', 'they']                                   1
# ['they', 'them']                                 1
# ['its']                                          1
# ['they', 'them', 'they', 'they']                 1
# ['his', 'he', 'him']                             1
# ['themselves', 'it']                             1
# ['them', 'your', 'it']                           1
# ['you', 'you']                                   1
# ['she', 'she', 'it']                             1
# ['your', 'you']                                  1
# ['him', 'him', 'his', 'them', 'them', 'it']      1
# ['they', 'them', 'their']                        1
# ['his', 'he', 'his', 'him']                      1
# ['himself']                                      1
# ['they', 'they', 'their']                        1
# ['her', 'she', 'her']                            1
# ['that', 'he']                                   1
# ['she', 'his']                                   1
# ['he', 'he', 'he']                               1
# ['he', 'his', 'he', 'he']                        1
# Name: Unnamed: 4, Length: 84, dtype: int64
